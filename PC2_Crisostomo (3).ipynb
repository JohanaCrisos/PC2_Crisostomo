# %%
import pandas as pd
link='https://github.com/JohanaCrisos/PC2_Crisostomo/raw/refs/heads/main/HDI.xlsx'
tabla=pd.read_excel(link, header=4)
tabla
# Out:
#     Unnamed: 0                                         Unnamed: 1  \
# 0     HDI rank                                            Country
# 1          NaN                                                NaN
# 2          NaN                        VERY HIGH HUMAN DEVELOPMENT
# 3            1                                        Switzerland
# 4            2                                             Norway
# ..         ...                                                ...
# 267        NaN                          Column 2: UNDESA (2022a).
# 268        NaN  Column 3: CEDLAS and World Bank (2022), ICF Ma...
# 269        NaN  Column 4: Barro and Lee (2018), ICF Macro Demo...
# 270        NaN  Column 5: IMF (2022), UNDESA (2022b), United N...
# 271        NaN  Column 6: Calculated based on data in columns ...
#
#     Human Development Index (HDI)   Unnamed: 3 Life expectancy at birth  \
# 0                            Value         NaN                  (years)
# ...

# %%
tabla.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Human Development Index (HDI) ',
#        'Unnamed: 3', 'Life expectancy at birth', 'Unnamed: 5',
#        'Expected years of schooling', 'Unnamed: 7', 'Mean years of schooling',
#        'Unnamed: 9', 'Gross national income (GNI) per capita', 'Unnamed: 11',
#        'GNI per capita rank minus HDI rank', 'Unnamed: 13', 'HDI rank'],
#       dtype='object')

# %%
#Eliminar filas y columnas innecesarias
toDrop=['Unnamed: 0','Unnamed: 3','Unnamed: 5','Unnamed: 7','Unnamed: 9','Unnamed: 11','Unnamed: 13','GNI per capita rank minus HDI rank', 'HDI rank']
tabla.drop(columns=toDrop, inplace=True)
tabla.drop(index=[0,1], inplace=True)

# %%
#quitar los espacios iniciales y finales de las columnas y sustituir
#los espacios entre lineas con _
tabla.columns=tabla.columns.str.strip().str.replace(r'\s+', '_', regex=True)
tabla.columns
# Out:
# Index(['Unnamed:_1', 'Human_Development_Index_(HDI)',
#        'Life_expectancy_at_birth', 'Expected_years_of_schooling',
#        'Mean_years_of_schooling', 'Gross_national_income_(GNI)_per_capita'],
#       dtype='object')

# %%
#Renombrar
newname={'Unnamed:_1':'Country','Human_Development_Index_(HDI)':'Human_Development_Index','Gross_national_income_(GNI)_per_capita':'Gross_national_income_per_capita'}
tabla.rename(columns=newname,inplace=True)

# %%
tabla
# Out:
#                                                Country  \
# 2                          VERY HIGH HUMAN DEVELOPMENT
# 3                                          Switzerland
# 4                                               Norway
# 5                                              Iceland
# 6                               Hong Kong, China (SAR)
# ..                                                 ...
# 267                          Column 2: UNDESA (2022a).
# 268  Column 3: CEDLAS and World Bank (2022), ICF Ma...
# 269  Column 4: Barro and Lee (2018), ICF Macro Demo...
# 270  Column 5: IMF (2022), UNDESA (2022b), United N...
# 271  Column 6: Calculated based on data in columns ...
#
#     Human_Development_Index Life_expectancy_at_birth  \
# 2                       NaN                      NaN
# 3                     0.962                  83.9872
# 4                     0.961                  83.2339
# 5                     0.959                  82.6782
# ...

# %%
#Eliminar filas con datos faltantes
tabla=tabla.dropna(axis='rows',how='any', ignore_index=True)
tabla
# Out:
#                                                Country  \
# 0                                          Switzerland
# 1                                               Norway
# 2                                              Iceland
# 3                               Hong Kong, China (SAR)
# 4                                            Australia
# ..                                                 ...
# 205                                 Sub-Saharan Africa
# 206                          Least developed countries
# 207                     Small island developing states
# 208  Organisation for Economic Co-operation and Dev...
# 209                                              World
#
#     Human_Development_Index Life_expectancy_at_birth  \
# 0                     0.962                  83.9872
# 1                     0.961                  83.2339
# 2                     0.959                  82.6782
# 3                     0.952                  85.4734
# ...

# %%
#Eliminar las final que no tengan nada que ver con Country
tabla=tabla.drop(index=range(195,210))
tabla
# Out:
#                                  Country Human_Development_Index  \
# 0                            Switzerland                   0.962
# 1                                 Norway                   0.961
# 2                                Iceland                   0.959
# 3                 Hong Kong, China (SAR)                   0.952
# 4                              Australia                   0.951
# ..                                   ...                     ...
# 190                          South Sudan                   0.385
# 191  Korea (Democratic People's Rep. of)                      ..
# 192                               Monaco                      ..
# 193                                Nauru                      ..
# 194                              Somalia                      ..
#
#     Life_expectancy_at_birth Expected_years_of_schooling  \
# 0                    83.9872                   16.500299
# 1                    83.2339                     18.1852
# ...

# %%
pip install unidecode

# %%
#Ahora analizaremos las columnas
#Nos aseguramos que los paises esten correctamente escritos
tabla['Country']=tabla.Country.str.title()

# %%
#Columna Human
tabla[tabla.Human_Development_Index.str.contains(r'\D',na=False)] #se identifica los valores que no contienen números
# Out:
#                                  Country Human_Development_Index  \
# 191  Korea (Democratic People'S Rep. Of)                      ..
# 192                               Monaco                      ..
# 193                                Nauru                      ..
# 194                              Somalia                      ..
#
#     Life_expectancy_at_birth Expected_years_of_schooling  \
# 191                  73.2845                    10.78317
# 192                  85.9463                          ..
# 193                   63.617                    11.69042
# 194                  55.2803                          ..
#
#     Mean_years_of_schooling Gross_national_income_per_capita
# 191                      ..                               ..
# 192                      ..                               ..
# 193                      ..                      17729.74084
# 194                      ..                       1017.96785

# %%
tabla[tabla.Expected_years_of_schooling.str.contains(r'\D',na=False)]
# Out:
#      Country Human_Development_Index Life_expectancy_at_birth  \
# 192   Monaco                      ..                  85.9463
# 194  Somalia                      ..                  55.2803
#
#     Expected_years_of_schooling Mean_years_of_schooling  \
# 192                          ..                      ..
# 194                          ..                      ..
#
#     Gross_national_income_per_capita
# 192                               ..
# 194                       1017.96785

# %%
tabla[tabla.Gross_national_income_per_capita.str.contains(r'\D',na=False)]
# Out:
#                                  Country Human_Development_Index  \
# 191  Korea (Democratic People'S Rep. Of)                      ..
# 192                               Monaco                      ..
#
#     Life_expectancy_at_birth Expected_years_of_schooling  \
# 191                  73.2845                    10.78317
# 192                  85.9463                          ..
#
#     Mean_years_of_schooling Gross_national_income_per_capita
# 191                      ..                               ..
# 192                      ..                               ..

# %%
tabla[tabla.Mean_years_of_schooling.str.contains(r'\D',na=False)]
# Out:
#                                  Country Human_Development_Index  \
# 191  Korea (Democratic People'S Rep. Of)                      ..
# 192                               Monaco                      ..
# 193                                Nauru                      ..
# 194                              Somalia                      ..
#
#     Life_expectancy_at_birth Expected_years_of_schooling  \
# 191                  73.2845                    10.78317
# 192                  85.9463                          ..
# 193                   63.617                    11.69042
# 194                  55.2803                          ..
#
#     Mean_years_of_schooling Gross_national_income_per_capita
# 191                      ..                               ..
# 192                      ..                               ..
# 193                      ..                      17729.74084
# 194                      ..                       1017.96785

# %%
pd.unique(tabla.Life_expectancy_at_birth[~tabla.Life_expectancy_at_birth.astype(str).str.contains(r'\d+\.\d+', regex=True)])
# Out:
# array([], dtype=object)

# %%
tabla.Human_Development_Index=pd.to_numeric(tabla.Human_Development_Index, errors='coerce')
tabla.Human_Development_Index
# Out:
# 0      0.962
# 1      0.961
# 2      0.959
# 3      0.952
# 4      0.951
#        ...
# 190    0.385
# 191      NaN
# 192      NaN
# 193      NaN
# 194      NaN
# Name: Human_Development_Index, Length: 195, dtype: float64

# %%
tabla.Life_expectancy_at_birth=pd.to_numeric(tabla.Life_expectancy_at_birth, errors='coerce')
tabla.Life_expectancy_at_birth
# Out:
# 0      83.9872
# 1      83.2339
# 2      82.6782
# 3      85.4734
# 4      84.5265
#         ...
# 190    54.9752
# 191    73.2845
# 192    85.9463
# 193    63.6170
# 194    55.2803
# Name: Life_expectancy_at_birth, Length: 195, dtype: float64

# %%
tabla.Expected_years_of_schooling=pd.to_numeric(tabla.Expected_years_of_schooling, errors='coerce')
tabla.Expected_years_of_schooling
# Out:
# 0      16.500299
# 1      18.185200
# 2      19.163059
# 3      17.278170
# 4      21.054590
#          ...
# 190     5.542510
# 191    10.783170
# 192          NaN
# 193    11.690420
# 194          NaN
# Name: Expected_years_of_schooling, Length: 195, dtype: float64

# %%
tabla.Mean_years_of_schooling=pd.to_numeric(tabla.Mean_years_of_schooling, errors='coerce')
tabla.Mean_years_of_schooling
# Out:
# 0      13.85966
# 1      13.00363
# 2      13.76717
# 3      12.22621
# 4      12.72682
#          ...
# 190     5.72614
# 191         NaN
# 192         NaN
# 193         NaN
# 194         NaN
# Name: Mean_years_of_schooling, Length: 195, dtype: float64

# %%
tabla.Gross_national_income_per_capita=pd.to_numeric(tabla.Gross_national_income_per_capita, errors='coerce')
tabla.Gross_national_income_per_capita
# Out:
# 0      66933.00454
# 1      64660.10622
# 2      55782.04981
# 3      62606.84540
# 4      49238.43335
#           ...
# 190      767.78700
# 191            NaN
# 192            NaN
# 193    17729.74084
# 194     1017.96785
# Name: Gross_national_income_per_capita, Length: 195, dtype: float64

# %%
tabla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country                           195 non-null    object
#  1   Human_Development_Index           191 non-null    float64
#  2   Life_expectancy_at_birth          195 non-null    float64
#  3   Expected_years_of_schooling       193 non-null    float64
#  4   Mean_years_of_schooling           191 non-null    float64
#  5   Gross_national_income_per_capita  193 non-null    float64
# dtypes: float64(5), object(1)
# memory usage: 9.3+ KB

# %%
#Categotización
tabla['Category']=pd.cut(tabla.Human_Development_Index,
                         bins=[0,0.549,0.7,0.8,1],
                         labels=['Low Human Development','Medium Human Development','High Human Development','Very High Human Development'],
                         ordered=True)
tabla
# Out:
#                                  Country  Human_Development_Index  \
# 0                            Switzerland                    0.962
# 1                                 Norway                    0.961
# 2                                Iceland                    0.959
# 3                 Hong Kong, China (Sar)                    0.952
# 4                              Australia                    0.951
# ..                                   ...                      ...
# 190                          South Sudan                    0.385
# 191  Korea (Democratic People'S Rep. Of)                      NaN
# 192                               Monaco                      NaN
# 193                                Nauru                      NaN
# 194                              Somalia                      NaN
#
#      Life_expectancy_at_birth  Expected_years_of_schooling  \
# 0                     83.9872                    16.500299
# ...

# %%
tabla[tabla.isnull().any(axis=1)] #ver los valores nulos
# Out:
#                                  Country  Human_Development_Index  \
# 191  Korea (Democratic People'S Rep. Of)                      NaN
# 192                               Monaco                      NaN
# 193                                Nauru                      NaN
# 194                              Somalia                      NaN
#
#      Life_expectancy_at_birth  Expected_years_of_schooling  \
# 191                   73.2845                     10.78317
# 192                   85.9463                          NaN
# 193                   63.6170                     11.69042
# 194                   55.2803                          NaN
#
#      Mean_years_of_schooling  Gross_national_income_per_capita Category
# 191                      NaN                               NaN      NaN
# 192                      NaN                               NaN      NaN
# 193                      NaN                       17729.74084      NaN
# ...

# %%
tabla.dropna(axis='rows',how='any',ignore_index=True) #ignorar los valores nulos
# Out:
#                       Country  Human_Development_Index  \
# 0                 Switzerland                    0.962
# 1                      Norway                    0.961
# 2                     Iceland                    0.959
# 3      Hong Kong, China (Sar)                    0.952
# 4                   Australia                    0.951
# ..                        ...                      ...
# 186                   Burundi                    0.426
# 187  Central African Republic                    0.404
# 188                     Niger                    0.400
# 189                      Chad                    0.394
# 190               South Sudan                    0.385
#
#      Life_expectancy_at_birth  Expected_years_of_schooling  \
# 0                     83.9872                    16.500299
# 1                     83.2339                    18.185200
# 2                     82.6782                    19.163059
# 3                     85.4734                    17.278170
# ...

# %%
#lo guardamos usando pickle
tabla.to_pickle("tabla.pkl")
dfPickle=pd.read_pickle("tabla.pkl")
dfPickle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 7 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country                           195 non-null    object
#  1   Human_Development_Index           191 non-null    float64
#  2   Life_expectancy_at_birth          195 non-null    float64
#  3   Expected_years_of_schooling       193 non-null    float64
#  4   Mean_years_of_schooling           191 non-null    float64
#  5   Gross_national_income_per_capita  193 non-null    float64
#  6   Category                          191 non-null    category
# dtypes: category(1), float64(5), object(1)
# memory usage: 9.5+ KB
